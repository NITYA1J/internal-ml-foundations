# %% [markdown]
# # Session 1 Embedded Tool Skill
# ## Loading Data and Identifying Inputs, Target, Units, and Observation
#
# This notebook introduces only the pandas operations needed for Session 1.

# %%
import pandas as pd

df = pd.read_csv("iris_workshop.csv")
df.head()

# %% [markdown]
# ## Inspect the dataset

# %%
print("Shape:", df.shape)
print("\nColumns:")
print(df.columns.tolist())
print("\nData types:")
print(df.dtypes)
print("\nMissing values:")
print(df.isna().sum())

# %% [markdown]
# ## Define the problem elements
#
# - Unit of observation: one flower
# - Inputs: petal length and petal width
# - Input units: centimeters
# - Target: species
# - Task: multiclass classification
# - Metric: accuracy

# %%
input_columns = ["PetalLength_cm", "PetalWidth_cm"]
target_column = "Species"

X = df[input_columns]
y = df[target_column]

print("Inputs:")
display(X.head())

print("\nTarget:")
display(y.head().to_frame())

# %% [markdown]
# ## Faculty adaptation
#
# Replace the entries below with one example from your discipline.

# %%
my_problem = {
    "Unit of observation": "",
    "Input variables": [],
    "Input units": [],
    "Target": "",
    "Model task": "",
    "Metric": ""
}

my_problem
